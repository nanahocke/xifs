# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import xifs
import cartopy.crs as ccrs
import math

# %%
import xifs.xifs as xifs

# %%
file1='ECE3_1m*.nc'

# %%
analysis_list=["seasmean_2t","seasmean_sp","glomean_crf","glomean_es",'glomean_tclw','glomean_tciw','glomean_sp','glomean_tcwv','glomean_lsp','glomean_cp','glomean_sf','glomean_sshf','glomean_slhf','glomean_msl','glomean_2t','glomean_2d','glomean_ssrd','glomean_strd','glomean_ssr','glomean_str','glomean_tsr','glomean_ttr','glomean_e','glomean_tsrc','glomean_ttrc','glomean_ssrc','glomean_strc','glomean_tisr','glomean_tp','glomean_skt']

# %%
result=xifs.analysis(analysis_list,file1)

# %%
result['seasmean_2t']
# Out:
# <xarray.DataArray 'seasmean_2t' (season: 4, lat: 192, lon: 384)>
# dask.array<stack, shape=(4, 192, 384), dtype=float64, chunksize=(1, 192, 384), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 -89.53 -88.59 -87.66 -86.72 ... 87.66 88.59 89.53
#   * lon      (lon) float32 0.4688 1.406 2.344 3.281 ... 356.7 357.7 358.6 359.5
#   * season   (season) object 'DJF' 'JJA' 'MAM' 'SON'
# Attributes:
#     standard_name:       surface_air_temperature
#     long_name:           2m air temperature
#     units:               K
#     online_operation:    average
#     interval_operation:  6 h
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 6 h)
