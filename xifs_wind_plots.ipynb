# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import xifs
import cartopy.crs as ccrs

# %%
path='/data/user/jkjellsson/esm-experiments/focioifs/focioifs-merge14/outdata/oifs/'
file='ECE3_1m_18500101_regular_pl.nc'

# %%
filename=path+file

# %%
result={}

# %%
result['polar_vortex']=xifs.polar_vortex(filename)
result['QBO']=xifs.QBO(filename)

# %%
result['polar_vortex'].plot();

# %%
result['QBO'].plot();

# %%
xifs.to_netcdf(result, 'output/output_wind_test.nc')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-24-a2e3f2ae6fd5> in <module>
# ----> 1 xifs.to_netcdf(result, 'output/output_wind_test.nc')
#
# ~/xifs/xifs.py in to_netcdf(d, path_name)
#      90     """d is a dictionary, path_name is a string, writes d on disk as netCDF"""
#      91     data=d.values()
# ---> 92     ds=xr.merge(data)
#      93     ds.to_netcdf(path=path_name)
#
# ~/miniconda3/envs/py3_std/lib/python3.7/site-packages/xarray/core/merge.py in merge(objects, compat, join, fill_value, combine_attrs)
#     881         join,
#     882         combine_attrs=combine_attrs,
# --> 883         fill_value=fill_value,
#     884     )
#     885     merged = Dataset._construct_direct(**merge_result._asdict())
#
# ...

# %%
result['QBO']
# Out:
# <xarray.DataArray 'u_Singapore' (month: 12, pressure_levels: 39)>
# array([[ 6.35566056e-01, -1.50535810e+00, -1.42047882e-01,
#          2.33654380e+00,  1.17842221e+00, -2.10560098e-01,
#         -3.46362305e+00, -3.84400129e+00, -4.84417009e+00,
#         -8.06573391e+00, -1.13160582e+01, -1.42581339e+01,
#         -1.73480835e+01, -1.86648350e+01, -1.51512470e+01,
#         -8.73168850e+00, -3.43806577e+00, -3.08536506e+00,
#         -1.56590605e+01, -8.09214115e+00,  8.73840523e+00,
#          1.44221163e+01,  1.41792469e+01,  7.05069828e+00,
#         -7.03717566e+00, -3.26280212e+01, -3.92977676e+01,
#         -3.33503342e+01, -1.76680717e+01, -7.52969503e+00,
#         -3.83064651e+00, -2.75134349e+00, -2.11427665e+00,
#         -1.59427002e-01,  1.95970643e+00,  5.80538511e+00,
#          8.63865185e+00,  9.86403370e+00,  8.12706566e+00],
#        [-1.03599600e-01, -2.83313990e+00, -2.62962580e+00,
#         -7.57654786e-01, -1.75611424e+00, -3.00605273e+00,
# ...
