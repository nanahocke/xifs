# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import xifs
import cartopy.crs as ccrs

# %% [markdown]
# ## globally averages variables and seasmean

# %%
file1='ECE3_1m_19790101-20191231_regular_sfc.nc'

# %%
analysis_list=["seasmean_2t","seasmean_sp","glomean_crf","glomean_es",'glomean_tclw','glomean_tciw','glomean_sp','glomean_tcwv','glomean_lsp','glomean_cp','glomean_sf','glomean_sshf','glomean_slhf','glomean_msl','glomean_2t','glomean_2d','glomean_ssrd','glomean_strd','glomean_ssr','glomean_str','glomean_tsr','glomean_ttr','glomean_e','glomean_tsrc','glomean_ttrc','glomean_ssrc','glomean_strc','glomean_tisr','glomean_tp','glomean_skt']

# %%
result=xifs.analysis(analysis_list,file1)

# %%
list_2D=analysis_list[2:]
seasons=['DJF', 'MAM', 'JJA', 'SON']

# %%
for l in list_2D:
    plt.figure(figsize=(15,5))
    result[l].plot();

# %%
for s in seasons:
    plt.figure(figsize=(10,5))
    p=result['seasmean_2t'].sel(season=s).plot(cmap='Spectral_r',
        subplot_kws=dict(projection=ccrs.Mollweide(0), facecolor="gray"),
        transform=ccrs.PlateCarree(),)
    p.axes.coastlines()

# %%
for s in seasons:
    plt.figure(figsize=(10,5))
    p=result['seasmean_sp'].sel(season=s).plot(cmap='Spectral_r',
        subplot_kws=dict(projection=ccrs.Mollweide(0), facecolor="gray"),
        transform=ccrs.PlateCarree(),)
    p.axes.coastlines()

# %%
xifs.to_netcdf(result,'output/output_test.nc')

# %% [markdown]
# ## wind files

# %%
path='/data/user/jkjellsson/esm-experiments/focioifs/focioifs-merge14/outdata/oifs/'
file='ECE3_1m_18500101_regular_pl.nc'
filename=path+file

# %%
wind=['polar_vortex', 'QBO']

# %%
wind_result=xifs.analysis(wind, filename)

# %%
wind_result['polar_vortex'].plot();

# %%
wind_result['QBO'].plot.contourf(y='pressure_levels', yscale='log', yincrease=False, levels=20);

# %%
xifs.to_netcdf(wind_result, 'output/output_windtest.nc')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-7-bf6a5201013f> in <module>
# ----> 1 xifs.to_netcdf(wind_result, 'output/output_windtest.nc')
#
# ~/xifs/xifs.py in to_netcdf(d, path_name)
#      94     """d is a dictionary, path_name is a string, writes d on disk as netCDF"""
#      95     data=d.values()
# ---> 96     ds=xr.merge(data)
#      97     ds.to_netcdf(path=path_name)
#
# ~/miniconda3/envs/py3_std/lib/python3.7/site-packages/xarray/core/merge.py in merge(objects, compat, join, fill_value, combine_attrs)
#     881         join,
#     882         combine_attrs=combine_attrs,
# --> 883         fill_value=fill_value,
#     884     )
#     885     merged = Dataset._construct_direct(**merge_result._asdict())
#
# ~/miniconda3/envs/py3_std/lib/python3.7/site-packages/xarray/core/merge.py in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     614
#     615     prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
# --> 616     variables, out_indexes = merge_collected(collected, prioritized, compat=compat)
#     617     assert_unique_multiindex_level_names(variables)
#     618
#
# ~/miniconda3/envs/py3_std/lib/python3.7/site-packages/xarray/core/merge.py in merge_collected(grouped, prioritized, compat)
#     227                 variables = [variable for variable, _ in elements_list]
#     228                 try:
# --> 229                     merged_vars[name] = unique_variable(name, variables, compat)
#     230                 except MergeError:
#     231                     if compat != "minimal":
#
# ~/miniconda3/envs/py3_std/lib/python3.7/site-packages/xarray/core/merge.py in unique_variable(name, variables, compat, equals)
#     140     if not equals:
#     141         raise MergeError(
# --> 142             f"conflicting values for variable {name!r} on objects to be combined. "
#     143             "You can skip this check by specifying compat='override'."
#     144         )
#
# MergeError: conflicting values for variable 'lat' on objects to be combined. You can skip this check by specifying compat='override'.
